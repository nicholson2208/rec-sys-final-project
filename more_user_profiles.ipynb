# %%
import pandas as pd
import numpy as np
import requests as re
import time
import os
import sqlite3
import json
import random
# from mastodon import Mastodon
import networkx as nx

import matplotlib.pyplot as plt

# %%
# pandas options
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
def select_relevant_following_fields(iterable, instance): 
    """
    Just a map to pull certain things out of the json
    
    """
    smaller_json = list(map(lambda x: 
                            dict(
                                id=x["id"],
                                acct=x["acct"],
                                url=x["url"], # so we can tell which server!
                                created_at=x["created_at"],
                                followers_count=x["followers_count"],
                                following_count=x["following_count"],
                                statuses_count=x["statuses_count"],
                                last_status_at=x["last_status_at"]
                            ), 
                            iterable
                           )
                       )
    
    # add the server
    new_list = []
    for a_dict in smaller_json:
        # add the server name
        
        # need both because there are different urls for local versus not
        a_dict["instance"] = a_dict["url"].split("@")[0].split("/users/")[0]
        
        #check that the user instance is the one we need
        if a_dict['instance'] == instance:
            new_list.append(a_dict)
   
    return new_list

# %%
def pull_profiles(file_path="data/profiles/", local_only=True, offset=0, stride=80, write=True):
    """
    
    """
    profiles_df = pd.DataFrame()
    chunk_df = pd.DataFrame()

    req_stem = "https://hci.social/api/v1/directory?limit=80&local={local_only}&order=new&offset={offset}"
    req_query = req_stem.format(offset=offset, local_only="true" if local_only else "false")
    r = re.get(req_query)

    try:
        profiles = r.json()
    except Exception as e:
        print(e, offset)

    ii = 0

    while len(profiles) > 0:
        # keep going until you run out!

        this_profiles_chunk = pd.DataFrame(select_relevant_fields(profiles))

        # TODO: Don't concat these because we don't want huge CSVs! 
        # the newest thing is at the top, so concat old to the new
        profiles_df = pd.concat([this_profiles_chunk, profiles_df], axis=0)

        # Dataframe for 10 interations
        chunk_df = pd.concat([this_profiles_chunk, chunk_df], axis=0)

        # find out your new min_id
        most_recent_created_time = this_profiles_chunk["created_at"].max()

        if (ii + 1) % 10 == 0:
            print("caching results") 
            if write:
                chunk_df.to_csv(file_path + "{}_profile_chunk_{}.csv".format("local" if local_only else "global", ii), index=False)
            chunk_df = pd.DataFrame()

        ii += 1
        offset += stride

        print("I am so proud of you, the last profile was created at {}".format(most_recent_created_time))

        # don't get booted off the API
        time.sleep(1)

        # make another call
        req_query = req_stem.format(offset=offset, local_only="true" if local_only else "false")
        r = re.get(req_query)

        try:
            profiles = r.json()
        except Exception as e:
            print(e, offset)


    print("DONE! You did so good!!")
            
    if write:
        profiles_df.to_csv(file_path + "hci_social_profiles_{}.csv".format("local" if local_only else "global"), index=False)
    
    return profiles_df

# %%
# local_profiles = pull_profiles(local_only=True)

# %% [markdown]
# ## Trying shit out
# - Get all the followers and following for the user
# - Concat them

# %%
users_profiles = pd.read_csv("data/profiles/hci_social_profiles_local.csv")

# %%
users_profiles.head()
# Out:
#                    id        acct                             url  \
# 0  108286624813793740         cqz         https://hci.social/@cqz
# 1  108286142941695868     Gillian     https://hci.social/@Gillian
# 2  108286014897638184   AndreaHCI   https://hci.social/@AndreaHCI
# 3  108285815791532398         izd         https://hci.social/@izd
# 4  108285424167487793  shirinfeiz  https://hci.social/@shirinfeiz
#
#                  created_at  followers_count  following_count  statuses_count  \
# 0  2022-05-12T00:00:00.000Z               48               20              24
# 1  2022-05-12T00:00:00.000Z              368              271              36
# 2  2022-05-11T00:00:00.000Z               13                9               1
# 3  2022-05-11T00:00:00.000Z               39               22              37
# 4  2022-05-11T00:00:00.000Z               12               20               0
#
#   last_status_at             instance
# 0     2023-11-03  https://hci.social/
# 1     2022-12-23  https://hci.social/
# 2     2022-12-26  https://hci.social/
# 3     2023-10-12  https://hci.social/
# 4            NaN  https://hci.social/

# %%
def get_this_user_network_on_local_instance(user_id, instance, which="following", verbose=False):
    """
    Either get followers or following for a specific ID
    
    Params:
        which (str):
            one of followers or following
        instance (str):
            name of hci.social
    
    
    """

    this_user_followers = []
    this_batch_follower_list = []

    followers_string = "https://hci.social/api/v1/accounts/{id}/{which}?limit={limit}"
    next_query = followers_string.format(id=user_id, limit=80, which=which)
    r = re.get(next_query)

    if verbose:
        print(next_query)

    
    # dumpster fire of a loop!
    while True:
        r = re.get(next_query)

        try:
            this_batch_follower_list = r.json()
            # please don't break! but if it does, check here first!
            next_query = str(r.headers["Link"]).split('>; rel="next",')[0].strip("<")

        except Exception as e:
            print(e, id)
            break

        if len(this_batch_follower_list) == 0:
            break

        this_user_followers.extend(select_relevant_following_fields(this_batch_follower_list, instance))

        if '; rel="prev"' in next_query:
            # I'm gonna puke
            break

        if verbose:
            print(next_query)
        
    return this_user_followers

# %%
test_user = get_this_user_network_on_local_instance(users_profiles.iloc[0]["id"], instance='https://hci.social/', which="followers")

len(test_user)
# Out:
# 25

# %%
all_users_df = users_profiles.copy()

# %%
this_user_df = pd.DataFrame.from_records(test_user,
                       columns=['id', 'acct', 'url', 'created_at','followers_count','following_count','statuses_count', 'last_status_at','instance'])

# %%
pd.concat([all_users_df, this_user_df])
# Out:
#                     id        acct                             url  \
# 0   108286624813793740         cqz         https://hci.social/@cqz
# 1   108286142941695868     Gillian     https://hci.social/@Gillian
# 2   108286014897638184   AndreaHCI   https://hci.social/@AndreaHCI
# 3   108285815791532398         izd         https://hci.social/@izd
# 4   108285424167487793  shirinfeiz  https://hci.social/@shirinfeiz
# ..                 ...         ...                             ...
# 20  108236223653826827         axz         https://hci.social/@axz
# 21  108280547247259304      kjfeng      https://hci.social/@kjfeng
# 22  108280517522446278     jbigham     https://hci.social/@jbigham
# 23  108236105999236686    msbernst    https://hci.social/@msbernst
# 24  108286710312907313    ruotongw    https://hci.social/@ruotongw
#
#                   created_at  followers_count  following_count  \
# 0   2022-05-12T00:00:00.000Z               48               20
# 1   2022-05-12T00:00:00.000Z              368              271
# 2   2022-05-11T00:00:00.000Z               13                9
# 3   2022-05-11T00:00:00.000Z               39               22
# 4   2022-05-11T00:00:00.000Z               12               20
# ..                       ...              ...              ...
# 20  2022-05-03T00:00:00.000Z             2421             1177
# 21  2022-05-11T00:00:00.000Z               85               30
# 22  2022-05-11T00:00:00.000Z             2895             1160
# 23  2022-05-03T00:00:00.000Z              857              230
# 24  2022-05-12T00:00:00.000Z               43               45
#
#     statuses_count last_status_at             instance
# 0               24     2023-11-03  https://hci.social/
# 1               36     2022-12-23  https://hci.social/
# 2                1     2022-12-26  https://hci.social/
# 3               37     2023-10-12  https://hci.social/
# 4                0            NaN  https://hci.social/
# ..             ...            ...                  ...
# 20             803     2023-11-19  https://hci.social/
# 21              53     2023-10-19  https://hci.social/
# 22            3850     2023-11-19  https://hci.social/
# 23              79     2023-10-23  https://hci.social/
# 24               1     2022-12-14  https://hci.social/
#
# [718 rows x 9 columns]

# %% [markdown]
# ## Expanding the users dataset

# %%
def create_network_df(user_id):
    users_followers = get_this_user_network_on_local_instance(user_id, instance='https://hci.social/', which="followers")
    users_followers = get_this_user_network_on_local_instance(user_id, instance='https://hci.social/', which="following")
    
    users_followers_df = pd.DataFrame.from_records(users_followers,
                       columns=['id', 'acct', 'url', 'created_at','followers_count','following_count','statuses_count', 'last_status_at','instance'])
    
    users_followeing_df = pd.DataFrame.from_records(users_followers,
                       columns=['id', 'acct', 'url', 'created_at','followers_count','following_count','statuses_count', 'last_status_at','instance'])
    
    concated_network = pd.concat([users_followers_df, users_followeing_df]).drop_duplicates().reset_index(drop=True)
    
    print("compeleted network for user:", user_id)
    time.sleep(np.random.rand(1)[0] * 3)
    
    return concated_network

# %%
for index, user in all_users_df.iterrows():
    this_user_df = create_network_df(user['id'])
    all_users_df = pd.concat([all_users_df, this_user_df])
    all_users_df = all_users_df.drop_duplicates(subset=['id'])

# %%
len(all_users_df)
# Out:
# 22094

# %%
all_users_df_clean = all_users_df.drop_duplicates(subset=['id'])

# %%
all_users_df_clean.reset_index(drop=True, inplace=True)

# %%
all_users_df_clean.to_csv("data/profiles/extended_df.csv")

# %%
all_users_df_clean[all_users_df_clean['acct'] == 'Anas']
# Out:
#                       id  acct                       url  \
# 1127  109245646986992073  Anas  https://hci.social/@Anas
#
#                     created_at followers_count following_count statuses_count  \
# 1127  2022-10-28T00:00:00.000Z              46              48             24
#
#      last_status_at             instance
# 1127     2023-11-11  https://hci.social/

# %% [markdown]
# ## Running another interation of the code to extend the dataset

# %%
for index, user in all_users_df_clean.iterrows():
    this_user_df = create_network_df(user['id'])
    all_users_df = pd.concat([all_users_df, this_user_df])
    all_users_df = all_users_df.drop_duplicates(subset=['id'])
# Out:
# compeleted network for user: 108286624813793740
# compeleted network for user: 108286142941695868
# compeleted network for user: 108286014897638184
# compeleted network for user: 108285815791532398
# compeleted network for user: 108285424167487793
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 108285175735137681
# compeleted network for user: 108284677476769450
# compeleted network for user: 108284650613162617
# compeleted network for user: 108284640329969016
# compeleted network for user: 108284496969846045
# compeleted network for user: 108284491496238772
# compeleted network for user: 108284472777287286
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 108284451199412068
# compeleted network for user: 108284448676877930
# compeleted network for user: 108284310168001085
# compeleted network for user: 108284264938521441
# compeleted network for user: 108284252022830475
# compeleted network for user: 108284088264614478
# compeleted network for user: 108284030727169733
# compeleted network for user: 108283688521349473
# compeleted network for user: 108283159503154369
# compeleted network for user: 108282799222285178
# compeleted network for user: 108282396254515498
# compeleted network for user: 108282263983363823
# compeleted network for user: 108282121554083968
# compeleted network for user: 108281690618697871
# compeleted network for user: 108281570708175251
# compeleted network for user: 108281524084893115
# compeleted network for user: 108281272957502394
# compeleted network for user: 108281249828953438
# compeleted network for user: 108280940426884986
# compeleted network for user: 108280883772198166
# compeleted network for user: 108280823921086184
# compeleted network for user: 108280798767686659
# compeleted network for user: 108280673743424065
# compeleted network for user: 108280666307635742
# compeleted network for user: 108280636951605587
# compeleted network for user: 108280589457569746
# compeleted network for user: 108280584635141598
# compeleted network for user: 108280578348007719
# compeleted network for user: 108280556926327188
# compeleted network for user: 108280517522446278
# compeleted network for user: 108256493310722699
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 108251943778162956
# compeleted network for user: 108241761241801856
# compeleted network for user: 108238706787360220
# compeleted network for user: 108238329972013885
# compeleted network for user: 108238146047010500
# compeleted network for user: 108236268879552821
# compeleted network for user: 108236223653826827
# compeleted network for user: 108236151346190358
# compeleted network for user: 108236105999236686
# compeleted network for user: 108233111945670878
# compeleted network for user: 109239187646874084
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 109239123920327087
# compeleted network for user: 109238149825705828
# compeleted network for user: 109237889751231917
# compeleted network for user: 109237690835839360
# compeleted network for user: 109237602689880132
# compeleted network for user: 109236568895395328
# compeleted network for user: 109235160789702125
# compeleted network for user: 108705317984600912
# compeleted network for user: 108671560839858743
# compeleted network for user: 108636326341438945
# compeleted network for user: 108609390260130507
# compeleted network for user: 108576125160353453
# compeleted network for user: 108533578543847055
# compeleted network for user: 108472085253269940
# compeleted network for user: 108449722370868684
# compeleted network for user: 108449015026872194
# compeleted network for user: 108440085737885433
# compeleted network for user: 108402599296023092
# compeleted network for user: 108382049560129320
# compeleted network for user: 108381185205431914
# compeleted network for user: 108371204668994690
# compeleted network for user: 108359672658516985
# compeleted network for user: 108357952719219784
# compeleted network for user: 108357904034860606
# 'link' <built-in function id>
# compeleted network for user: 108338598401282770
# compeleted network for user: 108332265809840423
# compeleted network for user: 108331017431124157
# compeleted network for user: 108330444995552013
# compeleted network for user: 108329702213205943
# compeleted network for user: 108321171925012578
# compeleted network for user: 108319681357082422
# compeleted network for user: 108314106935755255
# compeleted network for user: 108308315011514326
# 'link' <built-in function id>
# compeleted network for user: 108306573405659138
# compeleted network for user: 108303739138140052
# compeleted network for user: 108301130108495010
# compeleted network for user: 108297840722763221
# compeleted network for user: 108296544202399896
# compeleted network for user: 108296512779306308
# compeleted network for user: 108296399032560383
# compeleted network for user: 108295900253586397
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 108295866187110673
# compeleted network for user: 108295596024801996
# 'link' <built-in function id>
# compeleted network for user: 108295553415468896
# compeleted network for user: 108295519053079548
# compeleted network for user: 108295306378455187
# compeleted network for user: 108295302377295962
# compeleted network for user: 108295155506763457
# compeleted network for user: 108294799264594421
# compeleted network for user: 108294232371689285
# compeleted network for user: 108294169421594675
# compeleted network for user: 108293520870101150
# compeleted network for user: 108293497601172908
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 
# compeleted network for user: 109362484026350606
# compeleted network for user: 109362332319598452
# compeleted network for user: 109362237286967557
# compeleted network for user: 109361221296409077
# 'link' <built-in function id>
# compeleted network for user: 109360716146159362
# compeleted network for user: 109360052762288188
# 'link' <built-in function id>
# compeleted network for user: 109358630304172736
# compeleted network for user: 109357501168124817
# compeleted network for user: 109355729091271465
# compeleted network for user: 109354033122619826
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 109353571813090095
# compeleted network for user: 109353448516631051
# compeleted network for user: 109352733949558767
# compeleted network for user: 109351589160459409
# 'link' <built-in function id>
# compeleted network for user: 109351173675413230
# compeleted network for user: 109350290822680635
# compeleted network for user: 109349717979443119
# compeleted network for user: 109349606311170140
# compeleted network for user: 109348637371316982
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 109348486787892352
# 'link' <built-in function id>
# compeleted network for user: 109348286742916719
# compeleted network for user: 109347981308610118
# compeleted network for user: 109347113730051689
# 'link' <built-in function id>
# compeleted network for user: 109346245924080620
# compeleted network for user: 109346187192590707
# compeleted network for user: 109345732909824961
# compeleted network for user: 109345629138494164
# compeleted network for user: 109344285218309293
# compeleted network for user: 109342292535762166
# compeleted network for user: 109342075176221524
# compeleted network for user: 109341076081598299
# compeleted network for user: 109340063879946183
# compeleted network for user: 109338477579093945
# compeleted network for user: 109338042892496550
# compeleted network for user: 109337961591161088
# compeleted network for user: 109337887403549796
# compeleted network for user: 109337612351196917
# compeleted network for user: 109337194653166153
# compeleted network for user: 109336979683842433
# compeleted network for user: 109336789924968462
# compeleted network for user: 109336363760572989
# compeleted network for user: 109335608344000805
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 109334844569825630
# compeleted network for user: 109334134518865937
# compeleted network for user: 109333254556287519
# compeleted network for user: 109333061542469965
# compeleted network for user: 109332493763212372
# compeleted network for user: 109332380401603962
# compeleted network for user: 109331498917429645
# compeleted network for user: 109331453998993140
# compeleted network for user: 109331392555768057
# compeleted network for user: 109331215629870785
# compeleted network for user: 109327509890442688
# compeleted network for user: 109327362667974216
# compeleted network for user: 109327257285914702
# compeleted network for user: 109326896069618660
# compeleted network for user: 109467428920172086
# compeleted network for user: 109467229458219426
# 'link' <built-in function id>
# compeleted network for user: 109464463797526434
# compeleted network for user: 109463158338968179
# compeleted network for user: 109459389416719117
# 'link' <built-in function id>
# compeleted network for user: 109459209318299966
# compeleted network for user: 109453646455600410
# compeleted network for user: 109446769747731959
# compeleted network for user: 109446128190673417
# 'link' <built-in function id>
# compeleted network for user: 109444806043755147
# compeleted network for user: 109444142731904621
# compeleted network for user: 109443810750369110
# compeleted network for user: 109443203949546301
# compeleted network for user: 109440588905847086
# 'link' <built-in function id>
# compeleted network for user: 109438873964252797
# compeleted network for user: 109437916861827907
# 'link' <built-in function id>
# compeleted network for user: 109437550966253046
# compeleted network for user: 109435789444547632
# compeleted network for user: 109425854800281292
# compeleted network for user: 109424848775717723
# compeleted network for user: 109424675764302430
# compeleted network for user: 109423026572050531
# compeleted network for user: 109421985603907452
# compeleted network for user: 109420920073675301
# compeleted network for user: 109420132700253070
# 'link' <built-in function id>
# compeleted network for user: 109417599224172515
# compeleted network for user: 109417305385154660
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 109624967653681893
# compeleted network for user: 109327509890442688
# compeleted network for user: 109364927461335113
# compeleted network for user: 109444099528092693
# compeleted network for user: 109450755801581924
# 'link' <built-in function id>
# compeleted network for user: 109866632396522223
# compeleted network for user: 109300174841135506
# compeleted network for user: 109335406856892394
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 109257621270378650
# compeleted network for user: 109296628541552855
# compeleted network for user: 109383711092659925
# compeleted network for user: 109284048723312060
# compeleted network for user: 109345732909824961
# compeleted network for user: 109377086429283738
# compeleted network for user: 109364637871758195
# compeleted network for user: 109312653929403203
# compeleted network for user: 109365806130445647
# compeleted network for user: 109377676582106376
# compeleted network for user: 109296193037530235
# 'link' <built-in function id>
# compeleted network for user: 109384330474736206
# compeleted network for user: 109377355043143797
# compeleted network for user: 109377419215492633
# compeleted network for user: 109530554260821942
# compeleted network for user: 109421985603907452
# compeleted network for user: 110574158344377012
# compeleted network for user: 110236120706656777
# compeleted network for user: 109290570222750229
# compeleted network for user: 109305133765930823
# compeleted network for user: 110968626178296734
# compeleted network for user: 110968364242994284
# compeleted network for user: 109703464735275747
# compeleted network for user: 109305021889521005
# compeleted network for user: 109266527973134974
# 'link' <built-in function id>
# compeleted network for user: 109326838797468757
# 'link' <built-in function id>
# compeleted network for user: 108291053237005389
# compeleted network for user: 109374735509746349
# 'link' <built-in function id>
# compeleted network for user: 108291690714864085
# compeleted network for user: 109419560855112485
# compeleted network for user: 109288725464881287
# 'link' <built-in function id>
# 'link' <built-in function id>
# compeleted network for user: 108285507233040442
# compeleted network for user: 109259282237632973
# compeleted network for user: 109543392532148413
# compeleted network for user: 109310369258734486

# %%
len(all_users_df)
# Out:
# 2165

# %%
all_users_df_clean_extended = all_users_df.drop_duplicates(subset=['id'])
all_users_df_clean_extended.reset_index(drop=True, inplace=True)
all_users_df_clean_extended.to_csv("data/profiles/extended_df_complete.csv")

# %%
all_users_df_clean_extended.head()
# Out:
#                    id        acct                             url  \
# 0  108286624813793740         cqz         https://hci.social/@cqz
# 1  108286142941695868     Gillian     https://hci.social/@Gillian
# 2  108286014897638184   AndreaHCI   https://hci.social/@AndreaHCI
# 3  108285815791532398         izd         https://hci.social/@izd
# 4  108285424167487793  shirinfeiz  https://hci.social/@shirinfeiz
#
#                  created_at followers_count following_count statuses_count  \
# 0  2022-05-12T00:00:00.000Z              48              20             24
# 1  2022-05-12T00:00:00.000Z             368             271             36
# 2  2022-05-11T00:00:00.000Z              13               9              1
# 3  2022-05-11T00:00:00.000Z              39              22             37
# 4  2022-05-11T00:00:00.000Z              12              20              0
#
#   last_status_at             instance
# 0     2023-11-03  https://hci.social/
# 1     2022-12-23  https://hci.social/
# 2     2022-12-26  https://hci.social/
# 3     2023-10-12  https://hci.social/
# 4            NaN  https://hci.social/
